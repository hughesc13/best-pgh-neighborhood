# %% [markdown]
# We start by importing the necessary libraries:
# - `pandas` and `numpy` for data manipulation
# - `matplotlib.pyplot` for plotting
# - `geopandas` for any future geospatial work
# The `%matplotlib inline` command ensures that plots are displayed directly in the notebook.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas

# %% [markdown]
# We load the dataset `Playground_Equiptment.csv` into a DataFrame called `df` using `pd.read_csv()`. The `.head()` function displays the first few rows to get an overview of the data.

# %%
df = pd.read_csv("Playground_Equiptment.csv")
df.head()
# Out:
#    _id          id                          name    equipment_type  \
# 0    1  1780722587          Able Long Playground  Play Area 2 to 5
# 1    2   702514290         North Ave. Playground  Play Area 2 to 5
# 2    3  1267038491  Vietnam Veteran's Playground             Slide
# 3    4    14898932  Schenley Overlook Playground      Swing 2 Bays
# 4    5   204832406  Schenley Overlook Playground             Slide
#
#    manufacturer safety_surface_type ada_accessible  street_number  \
# 0  Little Tykes       Pour in Place              f          211.0
# 1     Playworld         SofSurfaces              f          377.0
# 2  Little Tykes         SofSurfaces              f          108.0
# 3  Little Tykes         SofSurfaces              t            NaN
# 4  Little Tykes         SofSurfaces              f            NaN
#
#               street         neighborhood  council_district  ward  \
# 0          Coast Ave            Beechview                 4    19
# ...

# %% [markdown]
# This section generates a bar chart showing the top 10 neighborhoods with the highest number of playground equipment entries:
#
# - `df["neighborhood"].value_counts()` counts the number of entries for each neighborhood.
# - `.head(10)` limits the result to the top 10 neighborhoods.
# - `.plot(kind="bar")` creates a bar chart.
# - `ax.set_ylabel()` and `ax.set_title()` add labels and a title to make the chart easier to interpret.
# - `plt.xticks(rotation=45, ha="right")` rotates the x-axis labels to prevent overlap.
# - `plt.show()` displays the final plot.

# %%
#i want to sort by neighborhood - which neighborhood has largest number of playground equiptment

fig, ax = plt.subplots(figsize=(12, 4))
df["neighborhood"].value_counts().head(10).plot(kind="bar", ax=ax)
ax.set_ylabel("Number of Playground Equipment")
ax.set_title("Top 10 Neighborhoods by Highest Count of Playground Equipment")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# **Conclusion:**
# I only plotted the top ten neighborhoods with the highest value counts in the bar chart. This makes the graph much more legible. In this scenario, value count refers to the number of playground equiptment in each neighborhood - in the dataset each row is one piece of playground equiptment, so if a neighborhood appears multiple times, that's because it has multiple pieces of playground equiptment. As you can see in the bar chart, Squirrel Hill South is the neighborhood with the most playground equiptment. Therefore, if we rank the best place to live in the summer by playground equiptment, squirrel hill south is the place to be!
